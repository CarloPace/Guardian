# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !unrar x "/content/drive/MyDrive/dataset_v2_yolo.rar" "/content/dataset/"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/dataset_v2_yolo.rar
#
# Creating    /content/dataset                                          OK
#   OK
# Creating    /content/dataset/test                                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !ls dataset
# Out:
# cpd.yaml  test	train  validation

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.5 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data=/content/dataset/cpd.yaml model=yolo11n.pt epochs=300 imgsz=480 patience=30 batch=32 save_period=30
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ## Test

# %%
# !yolo detect val data=/content/dataset/cpd.yaml model=/content/runs/detect/train/weights/best.pt split=test
# Out:
# Ultralytics 8.4.12 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 101 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 48.7±35.5 MB/s, size: 274.6 KB)
# val: Scanning /content/dataset/test... 152 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 152/152 664.6it/s 0.2s
# val: New cache created: /content/dataset/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.7it/s 5.9s
#                    all        152        281      0.902      0.873      0.917      0.655
#                  adult         77         97       0.87      0.835      0.883      0.668
#                  child         63        115      0.894      0.861      0.909      0.566
#                    pet         61         69      0.941      0.923      0.958      0.732
# ...

# %% [markdown]
# ## Download

# %%
import shutil
from google.colab import files

# 1. Zip the folder (replace 'folder_name' with your folder's name)
# This creates 'results.zip' from the folder '/content/runs/detect/train5'
shutil.make_archive('yolo_11n480', 'zip', '/content/runs/detect')

# 2. Download the zip file
files.download('yolo_11n480.zip')
