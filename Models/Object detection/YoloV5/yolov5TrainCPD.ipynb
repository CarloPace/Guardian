# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !unrar x "/content/drive/MyDrive/dataset_v3_yolo.rar" "/content/dataset/"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/dataset_v2_yolo.rar
#
# Creating    /content/dataset                                          OK
#   OK
# Creating    /content/dataset/test                                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !ls
# Out:
# dataset  drive	sample_data

# %%
# !ls dataset
# Out:
# cpd.yaml  test	train  validation

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.1 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data=/content/dataset/cpd.yaml model=yolov5nu.pt epochs=300 imgsz=640 patience=30 batch=48 save_period=30
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !rm -r runs

# %% [markdown]
# ## Test

# %%
# !yolo detect val data=/content/dataset/cpd.yaml model=/content/runs/detect/train/weights/best.pt split=test
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv5n summary (fused): 85 layers, 2,503,529 parameters, 0 gradients, 7.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 13.2±7.9 MB/s, size: 85.4 KB)
# val: Scanning /content/dataset/test... 152 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 152/152 388.7it/s 0.4s
# val: New cache created: /content/dataset/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.7it/s 6.0s
#                    all        152        281      0.912       0.86      0.924      0.636
#                  adult         77         97      0.866      0.864      0.917      0.666
#                  child         63        115      0.925      0.817      0.906       0.56
#                    pet         61         69      0.947      0.899      0.949      0.682
# Speed: 2.2ms preprocess, 5.2ms inference, 0.0ms loss, 2.3ms postprocess per image
# ...

# %% [markdown]
# ## Download

# %%
import shutil
from google.colab import files

# 1. Zip the folder (replace 'folder_name' with your folder's name)
# This creates 'results.zip' from the folder '/content/runs/detect/train5'
shutil.make_archive('yolo_v5nu_640', 'zip', '/content/runs/detect/val')

# 2. Download the zip file
files.download('yolo_v5nu_640.zip')
